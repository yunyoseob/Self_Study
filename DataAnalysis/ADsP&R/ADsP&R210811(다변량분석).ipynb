# %% [markdown]
# # ADsP 제 4과목 데이터 분석

# %% [markdown]
# 제 3절 다변량분석
# --

# %% [markdown]
# 수식 마크다운 참고: https://huni0318.github.io/blog/blog-etc/2020-12-21-markdown-tutorial2/

# %% [markdown]
# #상관분석

# %% [markdown]
# 상관분석: 데이터 안의 두 변수 간의 관계를 알아보기 위해 하는 분석. 두 변수의 상관관계를 알아보기 위해 상관계수를 이용
#
# - 상관계수
#
# - 피어슨 상관계수: 등간척도 이상으로 두 변수들 간의 상관관계를 측정하는 데 쓰임.
#
# - 스피어만 상관계수: 서열척도인 두 변수들의 상관관계를 측정하는데 사용

# %% [markdown]
# 공분산
#
# $ Cov(X,Y)=E[(X-\mu_{X})(Y-\mu_{Y})] $
#
# $\mu_{X}$: x의 기댓값
#
# $\mu_{Y}$: y의 기댓값

# %% [markdown]
# 피어슨 상관계수
# --

# %% [markdown]
# - 공분산의 크기는 $X$와 $Y$의 단위에 따라 영향을 받는데, 단위에 영향을 받지 않고 언제나 -1과 1사이의 값을 갖도록 함.
#
# $ \rho = Corr(X,Y)= \frac{Cov(X,Y)}{\sqrt{Var(X)var(Y)}} $
#
# - $ -1 \leq \rho \leq 1 $
#
# - 단, 독립이면 $ \rho = 0 $

# %% [markdown]
#  $ r = \frac{\sum_{i=1}^{n} (x_{i} - \bar{x})(y_{i} - \bar{y})}{\sqrt{\sum_{i=1}^{n}(x_{i}- \bar{x})^2}{\sqrt{\sum_{i=1}^{n} (y_{i} - \bar{y})^2}} }  $

# %% [markdown]
# 스피어만 상관계수
# --

# %% [markdown]
# - 피어슨 상관계수는 두 변수 간의 선형관계의 크기를 측저어하는 값으로 비선형적인 상관관계는 나타내지 못한다. 스피어만 상관계수는 두 변수 간의 비선형적인 관계도 나타낼 수 있는 값으로, 한 변수를 단조 증가 함수로 변환하여 다른 변수를 나타낼 수 있는 정도를 나타낸다. 스피어만의 상관계수는 두 변수를 모두 순위로 변환시킨 후, 두 순위 사이의 피어슨 상관계수로 정의가 된다. 수식은 다음과 같다.

# %% [markdown]
# $ \theta = \frac{\sum (r_{i} - \bar{r})(s_{i}-\bar{s})}{\sqrt{\sum(r_{i}-\bar{r})^2} \sqrt{\sum (s_{i} - \bar{s})^2}} $
#
# - $ -1 \leq \theta \leq 1 $
#
# - $r_{i}$는 $\{x_{1}, x_{2}, ... x_{n}\} $ 에서 $ x_{i}$의 순위
#
# - $s_{i}$는 $\{y_{1}, y_{2}, ... y_{n}\} $ 에서 $ y_{i}$의 순위

# %% [markdown]
# # 다차원 척도법

# %% [markdown]
# 다차원척도법은 여러 대상 간의 거리가 주어져 있을 때, 대상들을 동일한 상대적 거리를 가진 실수공간의 점들로 배치시키는 방법을 말한다.
#
#  주어진 거리는 추상적인 대상들간의 거리가 될 수도 있고, 실수공간에서의 거리가 될 수도 있다.
#
#  대상들을 2차원이나 3차원 실수공간의 점으로 대응 시킬 수 있다면 이 점들을 시각화 할 수 있고, 이는 관측치들 간의 전반적 관계에 대한 직관적 이해를 할 수 있게 도와준다.
#
#  따라서, 다차원 척도법은 주로 자료들의 상대적 관계를 이해하는 시각화 방법의 근간으로 주로 사용된다.

# %% [markdown]
# # 주성분 분석

# %% [markdown]
# 주성분 분석은 상관관계가 있는 고차원 자료를 저차원 자료로 변환시키는 방법으로, 자료의 차원을 축약시키는데 주로 사용된다.
#
# $p$차원 변수 $ X=(X_{1}, X_{2}, ... , X_{p})^T $ 가 있다고 할 때, $X$의 선형변환 $a^{T}X중 ||a|| = 1 이면서, 분산이 가장 큰 선형변환 Y_{1} = a_{1}^{T}X $를 첫번째 주성분이라고 한다.
#
# - 여기서 a는 p차원 벡터
#
#
#
# 정의에 따라 주성분들은 서로 상관관계가 없고, 주성분들의 분산의 합은 $X_{i}$들의 분산의 합과 같다. $a_{i}$를 $i$번째 주성분의 로딩이라고 한다.

# %% [markdown]
# # 시계열 예측

# %% [markdown]
# 시간의 흐름에 따라서 관측된 데이터를 시계열 자료라고 한다.

# %% [markdown]
# 정상성
# --

# %% [markdown]
# 시계열 분석을 위해서는 정상성을 만족해야 한다. 정상성은 시점에 상관없이 시계열의 특성이 일정하다는 것을 의미하며, 이를 만족한다는 것은 다음과 같은 것을 말한다.

# %% [markdown]
# 정상성
#
# 1. 평균이 일정하다.
#
# 2. 분산이 시점에 의존하지 않는다.
#
# 3. 공분산은 단지 시차에만 의존하고 시점 자체에는 의존하지 않는다.

# %% [markdown]
# - 이 중 하나라도 만족하지 못하는 경우의 시계열 자료를 비정상 시계열이라고 부르며, 대부분의 시계열 자료는 비정상 시계열 자료이다.
#
# - 따라서, 이상값 제거, 차분, 변환을 통해서 비정상시계열 자료를 정상 시계열 자료로 만든 후에 시계열 분석을 수행한다.
#
# - 차분이란 현 시점의 자료값에서 바로 전 시점의 자료값을 빼는 것을 말한다.
#
# - 여러 시점 전의 자료를 빼는 것: 계절차분(Seasonal Difference)

# %% [markdown]
# #시계열 모형

# %% [markdown]
# 자기회귀 모형(AR: Autoregrewssive model)
# --
#
#
# - 현 시점의 자료가 p 시점 전의 유한개의 과거 자료로 설명 될 수 있다는 의미이며  AR(p) 모형이라 한다.

# %% [markdown]
# $ Z_{t} = \phi_{1} Z_{t-1} + \phi_{2} Z_{t-2} + ... + \phi_{p} Z_{t-p} + a_{t} $
#
# - $Z_{t}$: 현재 시점의 시계열 자료
#
# - $Z_{t-1}, Z_{t-2},...,Z_{t-p}$: 1~p 시점 이전의 시계열 자료
#
# - $ \phi_{p} $: p 시점이 현재 시점에 어느 정도 영향을 주는지 나타내는 모수
#
# - $a_{t}$: 백색잡음과정(White noise process, 대표적인 정상 시계열), 시계열 분석에서 오차항을 의미한다.
#
# - AR(p)의 p에 따라, 우항에 있는 항의 개수에 달라진다.

# %% [markdown]
# 자기회귀모형인지 판단하기 위한 모형 식별을 위해서 자료에서 자기상관함수(ACF, Auto-Correlation Function)과 부분자기상관함수(PACF, Partial Auto-Correlation Function)을 이용하여 식별한다.
#
# - 일반적으로 자기회귀모형은 자기상관함수는 시차가 증가함에 따라 점차적으로 감소하고, 부분자기상관함수는 $p+1$ 시차 이후 급격히 감소하여 절단된 형태이며, 이를 AR(p) 모형이라고 판단한다.

# %% [markdown]
# 계량경제학 관련 자료 중 시계열 참고자료
# --
#
# https://github.com/yunyoseob/Study_at_PNU/blob/main/Econometrics/%EA%B3%84%EB%9F%89%EA%B2%BD%EC%A0%9C%ED%95%99%2013%EC%A3%BC%EC%B0%A8%20%EB%B3%B5%EC%8A%B5.pdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 용어 정리
# --
#
# 1. 최소제곱원칙(OLS):
#
# - 관측값들에서부터 회귀선까지의 수직거리를 제곱한 합이 최대한 작게 되도록 하는 방식
#
# 2. 최소제곱잔차(Least Squares Residual):
#
# - 관측값들에서부터 회귀선까지의 수직거리를 제곱한 합이  가장 작아지는 잔차
#
# 3. 최소제곱 추정량(Least Squares Estimator):
#
# - $ b_{1} = \bar{y} - b_{2} \bar{x} $ 에서 $ b_{1}, b_{2} $는 표본자료가 무엇이든지에 관계없이 사용할 수 있므여 확률 변수
#
# 4. 최소제곱 추정값 (Least Squares Estimate):
#
# - 어떤 변수를 넣어서 $ b_{1}, b_{2} $의 값을 구한 것
#
# 5. 불편추정량
#
# - 최소제곱 추정량(=확률)의 평균, 분산, 공분산, 확률분포, 최소제곱을 이용한 추정량은 다른 규칙을 이용해 구한 추정량과 어떻게 비교할 수 있는지를 평가해봐야 한다.
#
# - 선형회귀모형의 가정 SR.1~5를 충족한다고 할 때, 확률변수의 평균, 기댓값은 모수의 참값과 같다. 라는 것이고, 이를 수식으로 표현하면
# $ E(b_{1}) = \beta_{1}, E(b_{2})= \beta_{2} $
# 로 나타낼 수 있다.
#
# - 이러한 추정량을 "불편추정량"이라고 한다.(추정된 값인 $b_{1}$, $b_{2}$를 반복적으로 뽑아서 평균을 낸 값이 모수의 참값인 $ \beta_{1}, \beta_{2}$ 에 근접한다는 의미)
#
# 6. 가우스-마코프(Gauss-Markov) 정리, 최우수 선형 불편 추정량(Best Linear Unbiased Estimators, BLUE)
#
# - 단순회귀모형에서의 가정 SR.1~5를 만족 할 때, 최소제곱추정량 $b_{1}, b_{2}$는 $\beta_{1}, \beta_{2}$의 모든 선형 불편 추정량 중에서 최소의 분산을 가진다. 즉, $b_{1}, b_{2}$는 $\beta_{1}, \beta_{2}$의 "최우수 선형 불편 추정량"이다.
#
#
# 출처: https://m.blog.naver.com/schatz37/221522814483

# %% [markdown]
# 오차항
# --

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 더빈-왓슨(Dubin-Watson) 검정
# --

# %% [markdown]
# - 오차항에 자기상관이 있는지 없는지를 판단하기 위해 사용하는 검정법이다.

# %% [markdown]
# ![더빈왓슨.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 더빈-왓슨 검증 과정 단계별 요약
#
# 1. OLS 방식에 따라 $ \epsilon_{t} $ 를 구한다.
#
# 2. d의 값을 계산한다.
#
# 3. $ d_{U} $와 $ d_{L} $의 값을 찾아낸다.
#
# 4. 자기상관존재여부를 판단한다.
#
# 출처: https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=nlboman&logNo=23353211

# %% [markdown]
# 더빈-왓슨 검정법의 한계
#
# 1. 설명변수에는 종속변수의 과거값 $(Y_{t-1})$ 같은 확률변수가 들어가면 안된다.
#
# 2. d-통계량을 이용하기 위해서는 오차항 $ \epsilon_{t} $이 정규분포를 가져야 한다.
#
# 3. $ d_{L} $ 과 $ d_{U} $ 사이의 값에 대해서는 가설 검정을 할 수 없다.
#
# 4. AR(1)의 자기상관성만 측정하지, AR(P)까지 확장하지는 못한다.
#
# 출처: https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=jahyone20&logNo=220935609080
#
# 출처: https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=kwanseol&logNo=20088581319

# %% [markdown]
# 프라이스-윈스텐 방법
# --

# %% [markdown]
# 오차, 잔차의 독립성
#
# - 여러 학자가 자기상관성을 발견하고 이를 보정한 모형이 많이 제시되고 있다. 왜 자기상관성이 없어야 하나면 우리가 추정한 베타값이 BLUE(최우수 선형불편추정량)가 아니기 대문이다. 그 중 하나가 Prais-Winsten 모형이다.
#
# 출처: https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=kwanseol&logNo=20088581319

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 코크레인-오르커트 방법
# --

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. OLS 방식으로 $ \alpha $와 $ \beta_{1}$ 을 추정한다.
#
# 2. $ \rho $의 추정값인 r을 계산한다.
#
# 3. $ Y $를 $ Y_{t}^{'!} = Y_{t} - rY_{t-1} $ 그리고 $ X$를 $X_{t}^{!} = X_{t} - rX_{t-1} $로 변환시켜 변형회귀 모형에 대입시킨다.
#
# 4. 변형회귀모형에서 얻어진 잔차들을 분석하여 자기상관이 여전히 존재하는 가를 검색한다. 검색결과 자기상관이 존재하지 않으면, 이로써 작업을 종결하고 $\alpha$와 $\beta_{1}$을 사용하여 원회귀모형의 형태로 바꾼다. 이 때 회귀선의 기울기는 바뀌지 않으며 상수항만 바뀌게 된다.
#
#
# 출처: https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=nlboman&logNo=23353211

# %% [markdown]
# 이동평균모형(MA 모형)
# --

# %% [markdown]
# 시계열 자료를 모형화하는데, 자기회귀모형 다음으로 많이 쓰이는 모형이 이동평균모형(MA: Moving Average)이다.

# %% [markdown]
# $ Z_{t} = a_{t}- \theta_{t-1} a_{t-1} + \theta_{2} a_{t-2} + ... + \theta_{p} a_{t-p} $
#
# 이동평규놈형은 현 시점의 자료를 유한 개의 백색잡음의 선형결합으로 표현되었기 때문에 항상 정상성을 만족한다. 때문에 이동평균모형은 정상성 가정이 필요없다.
#
# - MA(p)의 p에 따라, 우항에 있는 항의 개수에 달라진다.

# %% [markdown]
# 이동평균모형을 판단하기 위한 모형 식별은 자기회귀모형과 마찬가지로 자기상관함수와 부분자기상관함수를 이용하여 식별하게 된다. 이동평균모형은 자기회귀모형과 반대로 자기상관함수는 $p+1$ 시차 이후 절단된 형태가 되고, 이 때는 $MA(p)$ 모형이라고 볼 수 있다. 그리고 부분자기상관함수는 점차 감소하는 형태를 띄게 된다.

# %% [markdown]
# 자기회귀누적이동평균모형(ARIMA 모형)
# --

# %% [markdown]
# 대부분의 많은 시계열 자료가 자기회귀누적이동평균모형(Autoregressive Integrated Moving Average Model)에 따른다.
#
# ARIMA 모형은 기본적으로 비정상 시계열 모형이기 때문에 차분이나 변환을 통해서 AR모형이나 MA모형, ARMA모형으로 정상화 할 수 있다.

# %% [markdown]
# ARIMA(p,d,q) 모형은 차수 p,d,q의 값에 따라 모형의 이름이 다르게 된다. 차수 p는 AR 모형과 관련이 있고, q는 MA모형과 관련이 있는 차수이다. d는 ARIMA에서 ARMA로 정상화 될 때 몇 번 차분했는지를 의미한다.
#
# d=0이면 ARMA(p,q)모형이라고 부르고,  이 모형은 정상성을 만족한다. p=0이면 IMA(d,q)모형이라 부르고, 이모형을 d번 차분하면 MA(q)모형이 된다. q=0이면 ARI(p,d) 모형이며, 이를 d번 차분한 시계열 모형이 AR(p) 모형을 따르게 된다.

# %% [markdown]
# 분해 시계열
# --

# %% [markdown]
# 분해 시계열이란 시계열에 영향을 주는 일반적인 요인을 시계열에서 분리해 분석하는 방법을 말하며, 회귀분석적인 방법을 주로 사용하고 있다. 시계열을 구성하는 요소는 다음 4가지로 분류된다.

# %% [markdown]
# 1. 추세요인
#
# - 자료의 그림을 그렸을 때 그 형태가 오르거나 내리는 추세를 따르는 경우가 있다. 물론 선형적으로 추세가 있는 것 이외에도 이차식의 형태를 취하거나 지수적 형태를 취할 수도 있는데, 이렇게 자료가 어떤 특정한 형태를 취할 때 추세요인(Trend factor)이 있다고 한다.

# %% [markdown]
# 2. 계절요인
#
# - 요일마다 반복되거나 일년 중 각 월에 의한 변화, 사분기 자료에서 각 분기에 의한 변화 등 고정된 주기에 따라 자료가 변화하는 경우가 있다. 이렇게 고정된 주기에 따라 자료가 변화할 경우 계절요인(Seasonal factor)이 있다고 한다.

# %% [markdown]
# 3. 순환요인
#
# - 명백한 경제적이나 자연적인 이유가 없이 알려지지 않은 주기를 가지고 변화하는 자료가 있다. 이와 같이 알려지지 않은 주기를 가지고 자료가 변화할 때, 순환요인(Cyclical factor)이 있다고 한다.

# %% [markdown]
# 4. 불규칙요인
#
# - 위 세가지의 요인으로 설명할 수 없는 회귀분석에서 오차에 해당하는 요인을 불규칙요인(Irregular factor)라고 한다.

# %% [markdown]
# 분해 시계열 분석법에서는 각 구성요인을 정확하게 분리하는 것이 중요하다. 그러나 각 요인을 정확하게 분리하는 것은 그리 쉽지 않다. 또한 분해 시계열 방법은 이론적인 약점이 있는 것으로도 알려져 있다. 하지만 경제학자들이나 조사통계학자들은 이러한 약점에도 널리 사용하고 있으며, 실제로 경제 분석이나 예측에서 이 방법은 성공적으로 사용되고 있다.

# %% [markdown]
#  $ Z_{t} = {f}(T_{t}, S_{t}, C_{t}, I_{t}) $
#
#  $ T_{t} $ : 경향(추세) 요인
#  $ S_{t} $ : 계절요인
#  $ C_{t} $ : 순환요인
#  $ I_{t} $ : 불규칙요인
#  $ Z_{t} $ : 시계열 값
#  $ {f} $: 미지의 함수
