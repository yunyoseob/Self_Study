# %% [markdown]
# #강화학습 실습(Grid World)

# %% [markdown]
# ![MDP상태.png](data:image/png;base64,...)

# %% [markdown]
# ![강화학습알고리즘흐름도.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #GridWorld.py 1st version

# %% [markdown]
# https://github.com/dennybritz/reinforcement-learning/blob/master/lib/envs/gridworld.py

# %%
import numpy as np

# global variables
BOARD_ROWS = 3
BOARD_COLS = 4
WIN_STATE = (0, 3)
LOSE_STATE = (1, 3)
START = (2, 0)
DETERMINISTIC = True


class State:
    def __init__(self, state=START):
        self.board = np.zeros([BOARD_ROWS, BOARD_COLS])
        self.board[1, 1] = -1
        self.state = state
        self.isEnd = False
        self.determine = DETERMINISTIC

    def giveReward(self):
        if self.state == WIN_STATE:
            return 1
        elif self.state == LOSE_STATE:
            return -1
        else:
            return 0

    def isEndFunc(self):
        if (self.state == WIN_STATE) or (self.state == LOSE_STATE):
            self.isEnd = True

    def nxtPosition(self, action):
        """
        action: up, down, left, right
        -------------
        0 | 1 | 2| 3|
        1 |
        2 |
        return next position
        """
        if self.determine:
            if action == "up":
                nxtState = (self.state[0] - 1, self.state[1])
            elif action == "down":
                nxtState = (self.state[0] + 1, self.state[1])
            elif action == "left":
                nxtState = (self.state[0], self.state[1] - 1)
            else:
                nxtState = (self.state[0], self.state[1] + 1)
            # if next state legal
            if (nxtState[0] >= 0) and (nxtState[0] <= (BOARD_ROWS -1)):
                if (nxtState[1] >= 0) and (nxtState[1] <= (BOARD_COLS -1)):
                    if nxtState != (1, 1):
                        return nxtState
            return self.state

    def showBoard(self):
        self.board[self.state] = 1
        for i in range(0, BOARD_ROWS):
            print('-----------------')
            out = '| '
            for j in range(0, BOARD_COLS):
                if self.board[i, j] == 1:
                    token = '*'
                if self.board[i, j] == -1:
                    token = 'z'
                if self.board[i, j] == 0:
                    token = '0'
                out += token + ' | '
            print(out)
        print('-----------------')


# Agent of player

class Agent:

    def __init__(self):
        self.states = []
        self.actions = ["up", "down", "left", "right"]
        self.State = State()
        self.lr = 0.2
        self.exp_rate = 0.3

        # initial state reward
        self.state_values = {}
        for i in range(BOARD_ROWS):
            for j in range(BOARD_COLS):
                self.state_values[(i, j)] = 0  # set initial value to 0

    def chooseAction(self):
        # choose action with most expected value
        mx_nxt_reward = 0
        action = ""

        if np.random.uniform(0, 1) <= self.exp_rate:
            action = np.random.choice(self.actions)
        else:
            # greedy action
            for a in self.actions:
                # if the action is deterministic
                nxt_reward = self.state_values[self.State.nxtPosition(a)]
                if nxt_reward >= mx_nxt_reward:
                    action = a
                    mx_nxt_reward = nxt_reward
        return action

    def takeAction(self, action):
        position = self.State.nxtPosition(action)
        return State(state=position)

    def reset(self):
        self.states = []
        self.State = State()

    def play(self, rounds=10):
        i = 0
        while i < rounds:
            # to the end of game back propagate reward
            if self.State.isEnd:
                # back propagate
                reward = self.State.giveReward()
                # explicitly assign end state to reward values
                self.state_values[self.State.state] = reward  # this is optional
                print("Game End Reward", reward)
                for s in reversed(self.states):
                    reward = self.state_values[s] + self.lr * (reward - self.state_values[s])
                    self.state_values[s] = round(reward, 3)
                self.reset()
                i += 1
            else:
                action = self.chooseAction()
                # append trace
                self.states.append(self.State.nxtPosition(action))
                print("current position {} action {}".format(self.State.state, action))
                # by taking the action, it reaches the next state
                self.State = self.takeAction(action)
                # mark is end
                self.State.isEndFunc()
                print("nxt state", self.State.state)
                print("---------------------")

    def showValues(self):
        for i in range(0, BOARD_ROWS):
            print('----------------------------------')
            out = '| '
            for j in range(0, BOARD_COLS):
                out += str(self.state_values[(i, j)]).ljust(6) + ' | '
            print(out)
        print('----------------------------------')


if __name__ == "__main__":
    ag = Agent()
    ag.play(50)
    print(ag.showValues())
# Out:
# current position (2, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action right
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action right
# nxt state (2, 2)
# ---------------------
# current position (2, 2) action right
# nxt state (2, 3)
# ---------------------
# current position (2, 3) action up
# nxt state (1, 3)
# ---------------------
# Game End Reward -1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action right
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action right
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action right
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action right
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action
# nxt state (2, 2)
# ---------------------
# current position (2, 2) action left
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action
# nxt state (2, 2)
# ---------------------
# current position (2, 2) action up
# nxt state (1, 2)
# ---------------------
# current position (1, 2) action up
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action left
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action left
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action up
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action down
# nxt state (1, 2)
# ---------------------
# current position (1, 2) action up
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action left
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action right
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action right
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action down
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action down
# nxt state (1, 2)
# ---------------------
# current position (1, 2) action up
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action down
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action right
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action left
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action left
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action left
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action left
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action up
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action down
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action down
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action left
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action up
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action down
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action left
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action down
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action right
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action down
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action right
# nxt state (2, 1)
# ---------------------
# current position (2, 1) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action up
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action down
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action left
# nxt state (2, 0)
# ---------------------
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# current position (2, 0) action up
# nxt state (1, 0)
# ---------------------
# current position (1, 0) action up
# nxt state (0, 0)
# ---------------------
# current position (0, 0) action right
# nxt state (0, 1)
# ---------------------
# current position (0, 1) action right
# nxt state (0, 2)
# ---------------------
# current position (0, 2) action right
# nxt state (0, 3)
# ---------------------
# Game End Reward 1
# ----------------------------------
# | 0.991  | 0.996  | 0.998  | 1.0    |
# ----------------------------------
# | 0.979  | 0      | 0.35   | -1.0   |
# ----------------------------------
# | 0.872  | 0.239  | -0.016 | -0.2   |
# ----------------------------------
# None

# %% [markdown]
# # GridWorld.py 2nd version
#
# https://github.com/dennybritz/reinforcement-learning/blob/master/lib/envs/gridworld.py

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import random
import collections
import numpy as np
import copy

# Hyperparameters
learning_rate = 0.0005
gamma = 0.98
buffer_limit = 50000
batch_size = 32



class GridWorld():
    def __init__(self, W, H):
        self.x = 2
        self.y = 2
        self.W = W-1
        self.H = H-1
        self.apple_x = random.randrange(start = 1, stop = self.H)
        self.apple_y = random.randrange(start = 1, stop = self.W)
        self.data = [[0] * 5 for _ in range(5)]

        # 사과 위치
        self.data[self.apple_x][self.apple_y] = 2

        # 사과를 찾은 횟수
        self.cnt = 0


    def step(self, a, show = False):
        # 0번 액션: 왼쪽, 1번 액션: 위, 2번 액션: 오른쪽, 3번 액션: 아래쪽
        if a == 0:
            self.move_left()
        elif a == 1:
            self.move_up()
        elif a == 2:
            self.move_right()
        elif a == 3:
            self.move_down()

        find = self.is_find()
        if find:
            reward = 1
        else:
            reward = -1  # 보상은 항상 -1로 고정

        if show:
            self.show_data()

        return np.array([self.x, self.y, self.apple_x, self.apple_y]), reward, find

    def move_right(self):
        self.y += 1
        if self.y > self.W:
            self.y = self.W

    def move_left(self):
        self.y -= 1
        if self.y < 0:
            self.y = 0

    def move_up(self):
        self.x -= 1
        if self.x < 0:
            self.x = 0

    def move_down(self):
        self.x += 1
        if self.x > self.H:
            self.x = self.H

    def is_find(self):
        if self.x == self.apple_x and self.y == self.apple_y:
            self.set_apple()
            return True
        else:
            return False

    def set_apple(self):
        X, Y = self.find_nothing()
        idx = random.randrange(start=0, stop = len(X))
        self.data[self.apple_x][self.apple_y] = 0 # 사과 위치 초기화
        self.apple_x = X[idx]
        self.apple_y = Y[idx]

        self.data[self.apple_x][self.apple_y] = 2  # 사과 위치

    def find_nothing(self):
        # 0의 위치 찾기 // 사과 제외
        X, Y = [], []
        for h in range(self.H+1):
            if sum(self.data[h]) < self.H+1 and 2 not in self.data[h]:
                for w in range(self.W+1):
                    if self.data[h][w] == 0:
                        X.append(h)
                        Y.append(w)
        return X, Y



    def get_state(self):
        return np.array([self.x, self.y, self.apple_x, self.apple_y])

    def reset(self):
        self.x = 0
        self.y = 0

        self.data[self.apple_x][self.apple_y] = 0

        self.apple_x = random.randrange(start=1, stop=self.H)
        self.apple_y = random.randrange(start=1, stop=self.W)

        return np.array([self.x, self.y, self.apple_x, self.apple_y])

    def show_data(self):
        data = copy.deepcopy(self.data)
        data[self.x][self.y] = -9

        for idx, row in enumerate(data):
            print(row)


class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)

    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)

    def size(self):
        return len(self.buffer)


class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 4)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0, 3)
        else:
            return out.argmax().item()


def train(q, q_target, memory, optimizer):
    for i in range(10):
        s, a, r, s_prime, done_mask = memory.sample(batch_size)

        q_out = q(s)
        q_a = q_out.gather(1, a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()



env = GridWorld(W = 5, H = 5)
q = Qnet()
q_target = Qnet()
q_target.load_state_dict(q.state_dict())
memory = ReplayBuffer()

print_interval = 20
score = 0.0
optimizer = optim.Adam(q.parameters(), lr=learning_rate)

for n_epi in range(10000):
    epsilon = max(0.01, 0.8 - 0.01 * (n_epi / 200))  # Linear annealing from 80% to 1%
    s = env.reset()
    find = False

    while not find:
        a = q.sample_action(torch.from_numpy(s).float(), epsilon)
        s_prime, r, find = env.step(a)
        done_mask = 0.0 if find else 1.0
        memory.put((s, a, r / 100.0, s_prime, done_mask))
        s = s_prime

        score += r
        if find:
            break

    if memory.size() > 2000:
        train(q, q_target, memory, optimizer)

    if n_epi % print_interval == 0 and n_epi != 0:
        q_target.load_state_dict(q.state_dict())
        print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
            n_epi, score / print_interval, memory.size(), epsilon * 100))

        score = 0.0
# Out:
# n_episode :20, score : -63.0, n_buffer : 1301, eps : 79.9%
# n_episode :40, score : -69.5, n_buffer : 2730, eps : 79.8%
# n_episode :60, score : -67.2, n_buffer : 4115, eps : 79.7%
# n_episode :80, score : -72.5, n_buffer : 5604, eps : 79.6%
# n_episode :100, score : -50.0, n_buffer : 6643, eps : 79.5%
# n_episode :120, score : -81.5, n_buffer : 8314, eps : 79.4%
# n_episode :140, score : -50.9, n_buffer : 9372, eps : 79.3%
# n_episode :160, score : -55.4, n_buffer : 10519, eps : 79.2%
# n_episode :180, score : -76.0, n_buffer : 12078, eps : 79.1%
# n_episode :200, score : -76.7, n_buffer : 13652, eps : 79.0%
# n_episode :220, score : -77.6, n_buffer : 15244, eps : 78.9%
# n_episode :240, score : -106.8, n_buffer : 17419, eps : 78.8%
# n_episode :260, score : -71.5, n_buffer : 18889, eps : 78.7%
# n_episode :280, score : -73.7, n_buffer : 20403, eps : 78.6%
# n_episode :300, score : -91.5, n_buffer : 22273, eps : 78.5%
# n_episode :320, score : -65.6, n_buffer : 23625, eps : 78.4%
# n_episode :340, score : -75.8, n_buffer : 25181, eps : 78.3%
# n_episode :360, score : -76.3, n_buffer : 26748, eps : 78.2%
# n_episode :380, score : -55.1, n_buffer : 27890, eps : 78.1%
# n_episode :400, score : -47.0, n_buffer : 28870, eps : 78.0%
# n_episode :420, score : -52.0, n_buffer : 29949, eps : 77.9%
# n_episode :440, score : -60.2, n_buffer : 31193, eps : 77.8%
# n_episode :460, score : -68.8, n_buffer : 32609, eps : 77.7%
# n_episode :480, score : -103.5, n_buffer : 34719, eps : 77.6%
# n_episode :500, score : -48.2, n_buffer : 35724, eps : 77.5%
# n_episode :520, score : -80.2, n_buffer : 37369, eps : 77.4%
# n_episode :540, score : -73.6, n_buffer : 38881, eps : 77.3%
# n_episode :560, score : -99.9, n_buffer : 40919, eps : 77.2%
# n_episode :580, score : -104.3, n_buffer : 43046, eps : 77.1%
# n_episode :600, score : -78.5, n_buffer : 44655, eps : 77.0%
# n_episode :620, score : -58.6, n_buffer : 45868, eps : 76.9%
# n_episode :640, score : -101.8, n_buffer : 47944, eps : 76.8%
# n_episode :660, score : -61.0, n_buffer : 49204, eps : 76.7%
# n_episode :680, score : -84.5, n_buffer : 50000, eps : 76.6%
# n_episode :700, score : -52.3, n_buffer : 50000, eps : 76.5%
# n_episode :720, score : -84.1, n_buffer : 50000, eps : 76.4%
# n_episode :740, score : -51.0, n_buffer : 50000, eps : 76.3%
# n_episode :760, score : -42.4, n_buffer : 50000, eps : 76.2%
# n_episode :780, score : -52.4, n_buffer : 50000, eps : 76.1%
# n_episode :800, score : -67.5, n_buffer : 50000, eps : 76.0%
# n_episode :820, score : -67.2, n_buffer : 50000, eps : 75.9%
# n_episode :840, score : -77.5, n_buffer : 50000, eps : 75.8%
# n_episode :860, score : -62.2, n_buffer : 50000, eps : 75.7%
# n_episode :880, score : -56.0, n_buffer : 50000, eps : 75.6%
# n_episode :900, score : -56.1, n_buffer : 50000, eps : 75.5%
# n_episode :920, score : -51.6, n_buffer : 50000, eps : 75.4%
# n_episode :940, score : -46.7, n_buffer : 50000, eps : 75.3%
# n_episode :960, score : -47.2, n_buffer : 50000, eps : 75.2%
# n_episode :980, score : -40.9, n_buffer : 50000, eps : 75.1%
# n_episode :1000, score : -80.8, n_buffer : 50000, eps : 75.0%
# n_episode :1020, score : -86.0, n_buffer : 50000, eps : 74.9%
# n_episode :1040, score : -85.8, n_buffer : 50000, eps : 74.8%
# n_episode :1060, score : -65.3, n_buffer : 50000, eps : 74.7%
# n_episode :1080, score : -95.2, n_buffer : 50000, eps : 74.6%
# n_episode :1100, score : -68.2, n_buffer : 50000, eps : 74.5%
# n_episode :1120, score : -33.6, n_buffer : 50000, eps : 74.4%
# n_episode :1140, score : -32.5, n_buffer : 50000, eps : 74.3%
# n_episode :1160, score : -46.4, n_buffer : 50000, eps : 74.2%
# n_episode :1180, score : -37.0, n_buffer : 50000, eps : 74.1%
# n_episode :1200, score : -50.6, n_buffer : 50000, eps : 74.0%
# n_episode :1220, score : -27.1, n_buffer : 50000, eps : 73.9%
# n_episode :1240, score : -37.0, n_buffer : 50000, eps : 73.8%
# n_episode :1260, score : -48.9, n_buffer : 50000, eps : 73.7%
# n_episode :1280, score : -74.8, n_buffer : 50000, eps : 73.6%
# n_episode :1300, score : -48.0, n_buffer : 50000, eps : 73.5%
# n_episode :1320, score : -42.1, n_buffer : 50000, eps : 73.4%
# n_episode :1340, score : -35.5, n_buffer : 50000, eps : 73.3%
# n_episode :1360, score : -38.6, n_buffer : 50000, eps : 73.2%
# n_episode :1380, score : -39.9, n_buffer : 50000, eps : 73.1%
# n_episode :1400, score : -44.0, n_buffer : 50000, eps : 73.0%
# n_episode :1420, score : -36.5, n_buffer : 50000, eps : 72.9%
# n_episode :1440, score : -44.9, n_buffer : 50000, eps : 72.8%
# n_episode :1460, score : -25.6, n_buffer : 50000, eps : 72.7%
# n_episode :1480, score : -48.3, n_buffer : 50000, eps : 72.6%
# n_episode :1500, score : -18.1, n_buffer : 50000, eps : 72.5%
# n_episode :1520, score : -62.6, n_buffer : 50000, eps : 72.4%
# n_episode :1540, score : -44.0, n_buffer : 50000, eps : 72.3%
# n_episode :1560, score : -22.2, n_buffer : 50000, eps : 72.2%
# n_episode :1580, score : -41.9, n_buffer : 50000, eps : 72.1%
# n_episode :1600, score : -48.8, n_buffer : 50000, eps : 72.0%
# n_episode :1620, score : -59.1, n_buffer : 50000, eps : 71.9%
# n_episode :1640, score : -73.7, n_buffer : 50000, eps : 71.8%
# n_episode :1660, score : -42.2, n_buffer : 50000, eps : 71.7%
# n_episode :1680, score : -38.3, n_buffer : 50000, eps : 71.6%
# n_episode :1700, score : -78.9, n_buffer : 50000, eps : 71.5%
# n_episode :1720, score : -45.6, n_buffer : 50000, eps : 71.4%
# n_episode :1740, score : -42.8, n_buffer : 50000, eps : 71.3%
# n_episode :1760, score : -37.6, n_buffer : 50000, eps : 71.2%
# n_episode :1780, score : -58.2, n_buffer : 50000, eps : 71.1%
# n_episode :1800, score : -23.0, n_buffer : 50000, eps : 71.0%
# n_episode :1820, score : -123.8, n_buffer : 50000, eps : 70.9%
# n_episode :1840, score : -24.9, n_buffer : 50000, eps : 70.8%
# n_episode :1860, score : -59.4, n_buffer : 50000, eps : 70.7%
# n_episode :1880, score : -41.3, n_buffer : 50000, eps : 70.6%
# n_episode :1900, score : -32.0, n_buffer : 50000, eps : 70.5%
# n_episode :1920, score : -67.0, n_buffer : 50000, eps : 70.4%
# n_episode :1940, score : -47.4, n_buffer : 50000, eps : 70.3%
# n_episode :1960, score : -70.6, n_buffer : 50000, eps : 70.2%
# n_episode :1980, score : -32.0, n_buffer : 50000, eps : 70.1%
# n_episode :2000, score : -42.4, n_buffer : 50000, eps : 70.0%
# n_episode :2020, score : -34.2, n_buffer : 50000, eps : 69.9%
# n_episode :2040, score : -17.3, n_buffer : 50000, eps : 69.8%
# n_episode :2060, score : -30.7, n_buffer : 50000, eps : 69.7%
# n_episode :2080, score : -24.6, n_buffer : 50000, eps : 69.6%
# n_episode :2100, score : -56.2, n_buffer : 50000, eps : 69.5%
# n_episode :2120, score : -18.1, n_buffer : 50000, eps : 69.4%
# n_episode :2140, score : -32.5, n_buffer : 50000, eps : 69.3%
# n_episode :2160, score : -28.6, n_buffer : 50000, eps : 69.2%
# n_episode :2180, score : -27.2, n_buffer : 50000, eps : 69.1%
# n_episode :2200, score : -27.2, n_buffer : 50000, eps : 69.0%
# n_episode :2220, score : -10.7, n_buffer : 50000, eps : 68.9%
# n_episode :2240, score : -13.5, n_buffer : 50000, eps : 68.8%
# n_episode :2260, score : -9.2, n_buffer : 50000, eps : 68.7%
# n_episode :2280, score : -8.7, n_buffer : 50000, eps : 68.6%
# n_episode :2300, score : -10.6, n_buffer : 50000, eps : 68.5%
# n_episode :2320, score : -10.3, n_buffer : 50000, eps : 68.4%
# n_episode :2340, score : -10.2, n_buffer : 50000, eps : 68.3%
# n_episode :2360, score : -8.8, n_buffer : 50000, eps : 68.2%
# n_episode :2380, score : -7.8, n_buffer : 50000, eps : 68.1%
# n_episode :2400, score : -11.3, n_buffer : 50000, eps : 68.0%
# n_episode :2420, score : -9.9, n_buffer : 50000, eps : 67.9%
# n_episode :2440, score : -8.9, n_buffer : 50000, eps : 67.8%
# n_episode :2460, score : -11.4, n_buffer : 50000, eps : 67.7%
# n_episode :2480, score : -13.4, n_buffer : 50000, eps : 67.6%
# n_episode :2500, score : -8.8, n_buffer : 50000, eps : 67.5%
# n_episode :2520, score : -7.2, n_buffer : 50000, eps : 67.4%
# n_episode :2540, score : -8.2, n_buffer : 50000, eps : 67.3%
# n_episode :2560, score : -9.1, n_buffer : 50000, eps : 67.2%
# n_episode :2580, score : -10.1, n_buffer : 50000, eps : 67.1%
# n_episode :2600, score : -8.8, n_buffer : 50000, eps : 67.0%
# n_episode :2620, score : -9.6, n_buffer : 50000, eps : 66.9%
# n_episode :2640, score : -9.2, n_buffer : 50000, eps : 66.8%
# n_episode :2660, score : -8.2, n_buffer : 50000, eps : 66.7%
# n_episode :2680, score : -11.1, n_buffer : 50000, eps : 66.6%
# n_episode :2700, score : -10.6, n_buffer : 50000, eps : 66.5%
# n_episode :2720, score : -5.9, n_buffer : 50000, eps : 66.4%
# n_episode :2740, score : -7.3, n_buffer : 50000, eps : 66.3%
# n_episode :2760, score : -7.6, n_buffer : 50000, eps : 66.2%
# n_episode :2780, score : -8.6, n_buffer : 50000, eps : 66.1%
# n_episode :2800, score : -8.0, n_buffer : 50000, eps : 66.0%
# n_episode :2820, score : -12.3, n_buffer : 50000, eps : 65.9%
# n_episode :2840, score : -8.2, n_buffer : 50000, eps : 65.8%
# n_episode :2860, score : -8.8, n_buffer : 50000, eps : 65.7%
# n_episode :2880, score : -10.0, n_buffer : 50000, eps : 65.6%
# n_episode :2900, score : -7.8, n_buffer : 50000, eps : 65.5%
# n_episode :2920, score : -7.9, n_buffer : 50000, eps : 65.4%
# n_episode :2940, score : -8.1, n_buffer : 50000, eps : 65.3%
# n_episode :2960, score : -8.9, n_buffer : 50000, eps : 65.2%
# n_episode :2980, score : -11.7, n_buffer : 50000, eps : 65.1%
# n_episode :3000, score : -9.3, n_buffer : 50000, eps : 65.0%
# n_episode :3020, score : -7.8, n_buffer : 50000, eps : 64.9%
# n_episode :3040, score : -8.0, n_buffer : 50000, eps : 64.8%
# n_episode :3060, score : -9.1, n_buffer : 50000, eps : 64.7%
# n_episode :3080, score : -7.3, n_buffer : 50000, eps : 64.6%
# n_episode :3100, score : -6.8, n_buffer : 50000, eps : 64.5%
# n_episode :3120, score : -6.7, n_buffer : 50000, eps : 64.4%
# n_episode :3140, score : -13.5, n_buffer : 50000, eps : 64.3%
# n_episode :3160, score : -10.2, n_buffer : 50000, eps : 64.2%
# n_episode :3180, score : -9.7, n_buffer : 50000, eps : 64.1%
# n_episode :3200, score : -7.0, n_buffer : 50000, eps : 64.0%
# n_episode :3220, score : -9.1, n_buffer : 50000, eps : 63.9%
# n_episode :3240, score : -6.9, n_buffer : 50000, eps : 63.8%
# n_episode :3260, score : -9.2, n_buffer : 50000, eps : 63.7%
# n_episode :3280, score : -9.1, n_buffer : 50000, eps : 63.6%
# n_episode :3300, score : -9.4, n_buffer : 50000, eps : 63.5%
# n_episode :3320, score : -10.1, n_buffer : 50000, eps : 63.4%
# n_episode :3340, score : -10.4, n_buffer : 50000, eps : 63.3%
# n_episode :3360, score : -9.3, n_buffer : 50000, eps : 63.2%
# n_episode :3380, score : -5.2, n_buffer : 50000, eps : 63.1%
# n_episode :3400, score : -7.7, n_buffer : 50000, eps : 63.0%
# n_episode :3420, score : -6.0, n_buffer : 50000, eps : 62.9%
# n_episode :3440, score : -11.3, n_buffer : 50000, eps : 62.8%
# n_episode :3460, score : -11.8, n_buffer : 50000, eps : 62.7%
# n_episode :3480, score : -6.5, n_buffer : 50000, eps : 62.6%
# n_episode :3500, score : -7.8, n_buffer : 50000, eps : 62.5%
# n_episode :3520, score : -7.7, n_buffer : 50000, eps : 62.4%
# n_episode :3540, score : -8.0, n_buffer : 50000, eps : 62.3%
# n_episode :3560, score : -8.3, n_buffer : 50000, eps : 62.2%
# n_episode :3580, score : -7.2, n_buffer : 50000, eps : 62.1%
# n_episode :3600, score : -7.9, n_buffer : 50000, eps : 62.0%
# n_episode :3620, score : -7.6, n_buffer : 50000, eps : 61.9%
# n_episode :3640, score : -11.0, n_buffer : 50000, eps : 61.8%
# n_episode :3660, score : -6.4, n_buffer : 50000, eps : 61.7%
# n_episode :3680, score : -10.4, n_buffer : 50000, eps : 61.6%
# n_episode :3700, score : -9.9, n_buffer : 50000, eps : 61.5%
# n_episode :3720, score : -7.2, n_buffer : 50000, eps : 61.4%
# n_episode :3740, score : -6.0, n_buffer : 50000, eps : 61.3%
# n_episode :3760, score : -11.1, n_buffer : 50000, eps : 61.2%
# n_episode :3780, score : -8.7, n_buffer : 50000, eps : 61.1%
# n_episode :3800, score : -6.9, n_buffer : 50000, eps : 61.0%
# n_episode :3820, score : -6.9, n_buffer : 50000, eps : 60.9%
# n_episode :3840, score : -8.6, n_buffer : 50000, eps : 60.8%
# n_episode :3860, score : -7.8, n_buffer : 50000, eps : 60.7%
# n_episode :3880, score : -8.7, n_buffer : 50000, eps : 60.6%
# n_episode :3900, score : -9.3, n_buffer : 50000, eps : 60.5%
# n_episode :3920, score : -5.8, n_buffer : 50000, eps : 60.4%
# n_episode :3940, score : -9.6, n_buffer : 50000, eps : 60.3%
# n_episode :3960, score : -7.2, n_buffer : 50000, eps : 60.2%
# n_episode :3980, score : -9.1, n_buffer : 50000, eps : 60.1%
# n_episode :4000, score : -5.5, n_buffer : 50000, eps : 60.0%
# n_episode :4020, score : -6.9, n_buffer : 50000, eps : 59.9%
# n_episode :4040, score : -7.7, n_buffer : 50000, eps : 59.8%
# n_episode :4060, score : -10.7, n_buffer : 50000, eps : 59.7%
# n_episode :4080, score : -10.4, n_buffer : 50000, eps : 59.6%
# n_episode :4100, score : -7.3, n_buffer : 50000, eps : 59.5%
# n_episode :4120, score : -8.2, n_buffer : 50000, eps : 59.4%
# n_episode :4140, score : -8.0, n_buffer : 50000, eps : 59.3%
# n_episode :4160, score : -5.5, n_buffer : 50000, eps : 59.2%
# n_episode :4180, score : -8.0, n_buffer : 50000, eps : 59.1%
# n_episode :4200, score : -7.3, n_buffer : 50000, eps : 59.0%
# n_episode :4220, score : -7.3, n_buffer : 50000, eps : 58.9%
# n_episode :4240, score : -6.7, n_buffer : 50000, eps : 58.8%
# n_episode :4260, score : -6.5, n_buffer : 50000, eps : 58.7%
# n_episode :4280, score : -7.0, n_buffer : 50000, eps : 58.6%
# n_episode :4300, score : -8.2, n_buffer : 50000, eps : 58.5%
# n_episode :4320, score : -7.5, n_buffer : 50000, eps : 58.4%
# n_episode :4340, score : -4.3, n_buffer : 50000, eps : 58.3%
# n_episode :4360, score : -5.4, n_buffer : 50000, eps : 58.2%
# n_episode :4380, score : -6.5, n_buffer : 50000, eps : 58.1%
# n_episode :4400, score : -5.5, n_buffer : 50000, eps : 58.0%
# n_episode :4420, score : -6.8, n_buffer : 50000, eps : 57.9%
# n_episode :4440, score : -5.0, n_buffer : 50000, eps : 57.8%
# n_episode :4460, score : -4.3, n_buffer : 50000, eps : 57.7%
# n_episode :4480, score : -6.2, n_buffer : 50000, eps : 57.6%
# n_episode :4500, score : -6.0, n_buffer : 50000, eps : 57.5%
# n_episode :4520, score : -6.5, n_buffer : 50000, eps : 57.4%
# n_episode :4540, score : -5.7, n_buffer : 50000, eps : 57.3%
# n_episode :4560, score : -8.1, n_buffer : 50000, eps : 57.2%
# n_episode :4580, score : -6.7, n_buffer : 50000, eps : 57.1%
# n_episode :4600, score : -6.5, n_buffer : 50000, eps : 57.0%
# n_episode :4620, score : -7.8, n_buffer : 50000, eps : 56.9%
# n_episode :4640, score : -7.9, n_buffer : 50000, eps : 56.8%
# n_episode :4660, score : -6.2, n_buffer : 50000, eps : 56.7%
# n_episode :4680, score : -6.1, n_buffer : 50000, eps : 56.6%
# n_episode :4700, score : -4.8, n_buffer : 50000, eps : 56.5%
# n_episode :4720, score : -6.8, n_buffer : 50000, eps : 56.4%
# n_episode :4740, score : -8.0, n_buffer : 50000, eps : 56.3%
# n_episode :4760, score : -7.7, n_buffer : 50000, eps : 56.2%
# n_episode :4780, score : -5.2, n_buffer : 50000, eps : 56.1%
# n_episode :4800, score : -6.5, n_buffer : 50000, eps : 56.0%
# n_episode :4820, score : -8.6, n_buffer : 50000, eps : 55.9%
# n_episode :4840, score : -8.2, n_buffer : 50000, eps : 55.8%
# n_episode :4860, score : -8.1, n_buffer : 50000, eps : 55.7%
# n_episode :4880, score : -4.1, n_buffer : 50000, eps : 55.6%
# n_episode :4900, score : -6.9, n_buffer : 50000, eps : 55.5%
# n_episode :4920, score : -3.9, n_buffer : 50000, eps : 55.4%
# n_episode :4940, score : -5.8, n_buffer : 50000, eps : 55.3%
# n_episode :4960, score : -7.8, n_buffer : 50000, eps : 55.2%
# n_episode :4980, score : -5.5, n_buffer : 50000, eps : 55.1%
# n_episode :5000, score : -6.7, n_buffer : 50000, eps : 55.0%
# n_episode :5020, score : -6.5, n_buffer : 50000, eps : 54.9%
# n_episode :5040, score : -7.5, n_buffer : 50000, eps : 54.8%
# n_episode :5060, score : -6.8, n_buffer : 50000, eps : 54.7%
# n_episode :5080, score : -5.0, n_buffer : 50000, eps : 54.6%
# n_episode :5100, score : -8.4, n_buffer : 50000, eps : 54.5%
# n_episode :5120, score : -5.1, n_buffer : 50000, eps : 54.4%
# n_episode :5140, score : -6.5, n_buffer : 50000, eps : 54.3%
# n_episode :5160, score : -5.2, n_buffer : 50000, eps : 54.2%
# n_episode :5180, score : -4.1, n_buffer : 50000, eps : 54.1%
# n_episode :5200, score : -6.5, n_buffer : 50000, eps : 54.0%
# n_episode :5220, score : -7.3, n_buffer : 50000, eps : 53.9%
# n_episode :5240, score : -6.8, n_buffer : 50000, eps : 53.8%
# n_episode :5260, score : -7.2, n_buffer : 50000, eps : 53.7%
# n_episode :5280, score : -4.8, n_buffer : 50000, eps : 53.6%
# n_episode :5300, score : -7.3, n_buffer : 50000, eps : 53.5%
# n_episode :5320, score : -6.4, n_buffer : 50000, eps : 53.4%
# n_episode :5340, score : -5.0, n_buffer : 50000, eps : 53.3%
# n_episode :5360, score : -6.1, n_buffer : 50000, eps : 53.2%
# n_episode :5380, score : -7.0, n_buffer : 50000, eps : 53.1%
# n_episode :5400, score : -7.0, n_buffer : 50000, eps : 53.0%
# n_episode :5420, score : -5.8, n_buffer : 50000, eps : 52.9%
# n_episode :5440, score : -6.4, n_buffer : 50000, eps : 52.8%
# n_episode :5460, score : -4.2, n_buffer : 50000, eps : 52.7%
# n_episode :5480, score : -7.9, n_buffer : 50000, eps : 52.6%
# n_episode :5500, score : -6.7, n_buffer : 50000, eps : 52.5%
# n_episode :5520, score : -3.9, n_buffer : 50000, eps : 52.4%
# n_episode :5540, score : -6.5, n_buffer : 50000, eps : 52.3%
# n_episode :5560, score : -7.0, n_buffer : 50000, eps : 52.2%
# n_episode :5580, score : -7.2, n_buffer : 50000, eps : 52.1%
# n_episode :5600, score : -5.9, n_buffer : 50000, eps : 52.0%
# n_episode :5620, score : -6.0, n_buffer : 50000, eps : 51.9%
# n_episode :5640, score : -6.5, n_buffer : 50000, eps : 51.8%
# n_episode :5660, score : -7.3, n_buffer : 50000, eps : 51.7%
# n_episode :5680, score : -6.6, n_buffer : 50000, eps : 51.6%
# n_episode :5700, score : -4.7, n_buffer : 50000, eps : 51.5%
# n_episode :5720, score : -5.0, n_buffer : 50000, eps : 51.4%
# n_episode :5740, score : -4.2, n_buffer : 50000, eps : 51.3%
# n_episode :5760, score : -6.4, n_buffer : 50000, eps : 51.2%
# n_episode :5780, score : -6.8, n_buffer : 50000, eps : 51.1%
# n_episode :5800, score : -5.6, n_buffer : 50000, eps : 51.0%
# n_episode :5820, score : -4.8, n_buffer : 50000, eps : 50.9%
# n_episode :5840, score : -6.2, n_buffer : 50000, eps : 50.8%
# n_episode :5860, score : -4.4, n_buffer : 50000, eps : 50.7%
# n_episode :5880, score : -5.4, n_buffer : 50000, eps : 50.6%
# n_episode :5900, score : -6.5, n_buffer : 50000, eps : 50.5%
# n_episode :5920, score : -5.5, n_buffer : 50000, eps : 50.4%
# n_episode :5940, score : -3.7, n_buffer : 50000, eps : 50.3%
# n_episode :5960, score : -5.8, n_buffer : 50000, eps : 50.2%
# n_episode :5980, score : -4.5, n_buffer : 50000, eps : 50.1%
# n_episode :6000, score : -8.0, n_buffer : 50000, eps : 50.0%
# n_episode :6020, score : -4.8, n_buffer : 50000, eps : 49.9%
# n_episode :6040, score : -6.0, n_buffer : 50000, eps : 49.8%
# n_episode :6060, score : -6.2, n_buffer : 50000, eps : 49.7%
# n_episode :6080, score : -6.0, n_buffer : 50000, eps : 49.6%
# n_episode :6100, score : -5.5, n_buffer : 50000, eps : 49.5%
# n_episode :6120, score : -6.2, n_buffer : 50000, eps : 49.4%
# n_episode :6140, score : -5.1, n_buffer : 50000, eps : 49.3%
# n_episode :6160, score : -5.2, n_buffer : 50000, eps : 49.2%
# n_episode :6180, score : -6.1, n_buffer : 50000, eps : 49.1%
# n_episode :6200, score : -4.2, n_buffer : 50000, eps : 49.0%
# n_episode :6220, score : -4.8, n_buffer : 50000, eps : 48.9%
# n_episode :6240, score : -6.3, n_buffer : 50000, eps : 48.8%
# n_episode :6260, score : -4.5, n_buffer : 50000, eps : 48.7%
# n_episode :6280, score : -6.3, n_buffer : 50000, eps : 48.6%
# n_episode :6300, score : -6.8, n_buffer : 50000, eps : 48.5%
# n_episode :6320, score : -5.6, n_buffer : 50000, eps : 48.4%
# n_episode :6340, score : -5.0, n_buffer : 50000, eps : 48.3%
# n_episode :6360, score : -5.5, n_buffer : 50000, eps : 48.2%
# n_episode :6380, score : -6.4, n_buffer : 50000, eps : 48.1%
# n_episode :6400, score : -6.5, n_buffer : 50000, eps : 48.0%
# n_episode :6420, score : -4.6, n_buffer : 50000, eps : 47.9%
# n_episode :6440, score : -5.5, n_buffer : 50000, eps : 47.8%
# n_episode :6460, score : -5.0, n_buffer : 50000, eps : 47.7%
# n_episode :6480, score : -5.7, n_buffer : 50000, eps : 47.6%
# n_episode :6500, score : -6.5, n_buffer : 50000, eps : 47.5%
# n_episode :6520, score : -5.5, n_buffer : 50000, eps : 47.4%
# n_episode :6540, score : -4.0, n_buffer : 50000, eps : 47.3%
# n_episode :6560, score : -4.3, n_buffer : 50000, eps : 47.2%
# n_episode :6580, score : -4.7, n_buffer : 50000, eps : 47.1%
# n_episode :6600, score : -5.7, n_buffer : 50000, eps : 47.0%
# n_episode :6620, score : -6.3, n_buffer : 50000, eps : 46.9%
# n_episode :6640, score : -4.9, n_buffer : 50000, eps : 46.8%
# n_episode :6660, score : -5.8, n_buffer : 50000, eps : 46.7%
# n_episode :6680, score : -5.6, n_buffer : 50000, eps : 46.6%
# n_episode :6700, score : -4.3, n_buffer : 50000, eps : 46.5%
# n_episode :6720, score : -4.3, n_buffer : 50000, eps : 46.4%
# n_episode :6740, score : -5.4, n_buffer : 50000, eps : 46.3%
# n_episode :6760, score : -5.0, n_buffer : 50000, eps : 46.2%
# n_episode :6780, score : -3.9, n_buffer : 50000, eps : 46.1%
# n_episode :6800, score : -4.3, n_buffer : 50000, eps : 46.0%
# n_episode :6820, score : -5.7, n_buffer : 50000, eps : 45.9%
# n_episode :6840, score : -6.6, n_buffer : 50000, eps : 45.8%
# n_episode :6860, score : -5.5, n_buffer : 50000, eps : 45.7%
# n_episode :6880, score : -6.7, n_buffer : 50000, eps : 45.6%
# n_episode :6900, score : -4.3, n_buffer : 50000, eps : 45.5%
# n_episode :6920, score : -4.8, n_buffer : 50000, eps : 45.4%
# n_episode :6940, score : -5.7, n_buffer : 50000, eps : 45.3%
# n_episode :6960, score : -3.5, n_buffer : 50000, eps : 45.2%
# n_episode :6980, score : -4.0, n_buffer : 50000, eps : 45.1%
# n_episode :7000, score : -5.3, n_buffer : 50000, eps : 45.0%
# n_episode :7020, score : -7.0, n_buffer : 50000, eps : 44.9%
# n_episode :7040, score : -6.2, n_buffer : 50000, eps : 44.8%
# n_episode :7060, score : -4.6, n_buffer : 50000, eps : 44.7%
# n_episode :7080, score : -4.3, n_buffer : 50000, eps : 44.6%
# n_episode :7100, score : -3.7, n_buffer : 50000, eps : 44.5%
# n_episode :7120, score : -3.8, n_buffer : 50000, eps : 44.4%
# n_episode :7140, score : -4.6, n_buffer : 50000, eps : 44.3%
# n_episode :7160, score : -5.3, n_buffer : 50000, eps : 44.2%
# n_episode :7180, score : -5.5, n_buffer : 50000, eps : 44.1%
# n_episode :7200, score : -5.3, n_buffer : 50000, eps : 44.0%
# n_episode :7220, score : -4.4, n_buffer : 50000, eps : 43.9%
# n_episode :7240, score : -4.8, n_buffer : 50000, eps : 43.8%
# n_episode :7260, score : -4.5, n_buffer : 50000, eps : 43.7%
# n_episode :7280, score : -5.2, n_buffer : 50000, eps : 43.6%
# n_episode :7300, score : -3.9, n_buffer : 50000, eps : 43.5%
# n_episode :7320, score : -6.0, n_buffer : 50000, eps : 43.4%
# n_episode :7340, score : -5.3, n_buffer : 50000, eps : 43.3%
# n_episode :7360, score : -5.3, n_buffer : 50000, eps : 43.2%
# n_episode :7380, score : -5.7, n_buffer : 50000, eps : 43.1%
# n_episode :7400, score : -4.8, n_buffer : 50000, eps : 43.0%
# n_episode :7420, score : -3.9, n_buffer : 50000, eps : 42.9%
# n_episode :7440, score : -4.2, n_buffer : 50000, eps : 42.8%
# n_episode :7460, score : -6.2, n_buffer : 50000, eps : 42.7%
# n_episode :7480, score : -4.7, n_buffer : 50000, eps : 42.6%
# n_episode :7500, score : -6.3, n_buffer : 50000, eps : 42.5%
# n_episode :7520, score : -2.9, n_buffer : 50000, eps : 42.4%
# n_episode :7540, score : -4.5, n_buffer : 50000, eps : 42.3%
# n_episode :7560, score : -3.8, n_buffer : 50000, eps : 42.2%
# n_episode :7580, score : -4.6, n_buffer : 50000, eps : 42.1%
# n_episode :7600, score : -5.4, n_buffer : 50000, eps : 42.0%
# n_episode :7620, score : -5.3, n_buffer : 50000, eps : 41.9%
# n_episode :7640, score : -3.4, n_buffer : 50000, eps : 41.8%
# n_episode :7660, score : -5.5, n_buffer : 50000, eps : 41.7%
# n_episode :7680, score : -3.8, n_buffer : 50000, eps : 41.6%
# n_episode :7700, score : -5.2, n_buffer : 50000, eps : 41.5%
# n_episode :7720, score : -6.5, n_buffer : 50000, eps : 41.4%
# n_episode :7740, score : -4.8, n_buffer : 50000, eps : 41.3%
# n_episode :7760, score : -5.2, n_buffer : 50000, eps : 41.2%
# n_episode :7780, score : -5.4, n_buffer : 50000, eps : 41.1%
# n_episode :7800, score : -5.0, n_buffer : 50000, eps : 41.0%
# n_episode :7820, score : -3.2, n_buffer : 50000, eps : 40.9%
# n_episode :7840, score : -4.8, n_buffer : 50000, eps : 40.8%
# n_episode :7860, score : -5.5, n_buffer : 50000, eps : 40.7%
# n_episode :7880, score : -4.5, n_buffer : 50000, eps : 40.6%
# n_episode :7900, score : -3.4, n_buffer : 50000, eps : 40.5%
# n_episode :7920, score : -4.1, n_buffer : 50000, eps : 40.4%
# n_episode :7940, score : -3.6, n_buffer : 50000, eps : 40.3%
# n_episode :7960, score : -6.1, n_buffer : 50000, eps : 40.2%
# n_episode :7980, score : -3.2, n_buffer : 50000, eps : 40.1%
# n_episode :8000, score : -5.4, n_buffer : 50000, eps : 40.0%
# n_episode :8020, score : -4.2, n_buffer : 50000, eps : 39.9%
# n_episode :8040, score : -4.3, n_buffer : 50000, eps : 39.8%
# n_episode :8060, score : -6.8, n_buffer : 50000, eps : 39.7%
# n_episode :8080, score : -3.2, n_buffer : 50000, eps : 39.6%
# n_episode :8100, score : -5.0, n_buffer : 50000, eps : 39.5%
# n_episode :8120, score : -3.7, n_buffer : 50000, eps : 39.4%
# n_episode :8140, score : -4.7, n_buffer : 50000, eps : 39.3%
# n_episode :8160, score : -3.5, n_buffer : 50000, eps : 39.2%
# n_episode :8180, score : -4.1, n_buffer : 50000, eps : 39.1%
# n_episode :8200, score : -4.6, n_buffer : 50000, eps : 39.0%
# n_episode :8220, score : -4.6, n_buffer : 50000, eps : 38.9%
# n_episode :8240, score : -4.7, n_buffer : 50000, eps : 38.8%
# n_episode :8260, score : -4.6, n_buffer : 50000, eps : 38.7%
# n_episode :8280, score : -4.2, n_buffer : 50000, eps : 38.6%
# n_episode :8300, score : -4.2, n_buffer : 50000, eps : 38.5%
# n_episode :8320, score : -4.8, n_buffer : 50000, eps : 38.4%
# n_episode :8340, score : -4.5, n_buffer : 50000, eps : 38.3%
# n_episode :8360, score : -3.8, n_buffer : 50000, eps : 38.2%
# n_episode :8380, score : -3.4, n_buffer : 50000, eps : 38.1%
# n_episode :8400, score : -4.7, n_buffer : 50000, eps : 38.0%
# n_episode :8420, score : -4.5, n_buffer : 50000, eps : 37.9%
# n_episode :8440, score : -3.5, n_buffer : 50000, eps : 37.8%
# n_episode :8460, score : -5.0, n_buffer : 50000, eps : 37.7%
# n_episode :8480, score : -3.8, n_buffer : 50000, eps : 37.6%
# n_episode :8500, score : -3.2, n_buffer : 50000, eps : 37.5%
# n_episode :8520, score : -5.0, n_buffer : 50000, eps : 37.4%
# n_episode :8540, score : -4.5, n_buffer : 50000, eps : 37.3%
# n_episode :8560, score : -5.3, n_buffer : 50000, eps : 37.2%
# n_episode :8580, score : -3.5, n_buffer : 50000, eps : 37.1%
# n_episode :8600, score : -4.0, n_buffer : 50000, eps : 37.0%
# n_episode :8620, score : -3.6, n_buffer : 50000, eps : 36.9%
# n_episode :8640, score : -4.3, n_buffer : 50000, eps : 36.8%
# n_episode :8660, score : -3.9, n_buffer : 50000, eps : 36.7%
# n_episode :8680, score : -5.5, n_buffer : 50000, eps : 36.6%
# n_episode :8700, score : -4.5, n_buffer : 50000, eps : 36.5%
# n_episode :8720, score : -4.5, n_buffer : 50000, eps : 36.4%
# n_episode :8740, score : -3.7, n_buffer : 50000, eps : 36.3%
# n_episode :8760, score : -4.7, n_buffer : 50000, eps : 36.2%
# n_episode :8780, score : -5.2, n_buffer : 50000, eps : 36.1%
# n_episode :8800, score : -4.0, n_buffer : 50000, eps : 36.0%
# n_episode :8820, score : -6.2, n_buffer : 50000, eps : 35.9%
# n_episode :8840, score : -4.2, n_buffer : 50000, eps : 35.8%
# n_episode :8860, score : -4.0, n_buffer : 50000, eps : 35.7%
# n_episode :8880, score : -3.5, n_buffer : 50000, eps : 35.6%
# n_episode :8900, score : -4.8, n_buffer : 50000, eps : 35.5%
# n_episode :8920, score : -4.0, n_buffer : 50000, eps : 35.4%
# n_episode :8940, score : -2.9, n_buffer : 50000, eps : 35.3%
# n_episode :8960, score : -4.4, n_buffer : 50000, eps : 35.2%
# n_episode :8980, score : -3.0, n_buffer : 50000, eps : 35.1%
# n_episode :9000, score : -3.5, n_buffer : 50000, eps : 35.0%
# n_episode :9020, score : -3.9, n_buffer : 50000, eps : 34.9%
# n_episode :9040, score : -3.6, n_buffer : 50000, eps : 34.8%
# n_episode :9060, score : -5.2, n_buffer : 50000, eps : 34.7%
# n_episode :9080, score : -3.0, n_buffer : 50000, eps : 34.6%
# n_episode :9100, score : -4.7, n_buffer : 50000, eps : 34.5%
# n_episode :9120, score : -3.1, n_buffer : 50000, eps : 34.4%
# n_episode :9140, score : -3.4, n_buffer : 50000, eps : 34.3%
# n_episode :9160, score : -4.0, n_buffer : 50000, eps : 34.2%
# n_episode :9180, score : -4.3, n_buffer : 50000, eps : 34.1%
# n_episode :9200, score : -3.9, n_buffer : 50000, eps : 34.0%
# n_episode :9220, score : -3.5, n_buffer : 50000, eps : 33.9%
# n_episode :9240, score : -3.7, n_buffer : 50000, eps : 33.8%
# n_episode :9260, score : -4.4, n_buffer : 50000, eps : 33.7%
# n_episode :9280, score : -4.4, n_buffer : 50000, eps : 33.6%
# n_episode :9300, score : -3.9, n_buffer : 50000, eps : 33.5%
# n_episode :9320, score : -3.8, n_buffer : 50000, eps : 33.4%
# n_episode :9340, score : -4.2, n_buffer : 50000, eps : 33.3%
# n_episode :9360, score : -3.4, n_buffer : 50000, eps : 33.2%
# n_episode :9380, score : -3.4, n_buffer : 50000, eps : 33.1%
# n_episode :9400, score : -4.4, n_buffer : 50000, eps : 33.0%
# n_episode :9420, score : -3.6, n_buffer : 50000, eps : 32.9%
# n_episode :9440, score : -4.0, n_buffer : 50000, eps : 32.8%
# n_episode :9460, score : -3.0, n_buffer : 50000, eps : 32.7%
# n_episode :9480, score : -4.5, n_buffer : 50000, eps : 32.6%
# n_episode :9500, score : -4.3, n_buffer : 50000, eps : 32.5%
# n_episode :9520, score : -4.3, n_buffer : 50000, eps : 32.4%
# n_episode :9540, score : -3.6, n_buffer : 50000, eps : 32.3%
# n_episode :9560, score : -3.8, n_buffer : 50000, eps : 32.2%
# n_episode :9580, score : -5.6, n_buffer : 50000, eps : 32.1%
# n_episode :9600, score : -3.4, n_buffer : 50000, eps : 32.0%
# n_episode :9620, score : -4.0, n_buffer : 50000, eps : 31.9%
# n_episode :9640, score : -6.1, n_buffer : 50000, eps : 31.8%
# n_episode :9660, score : -3.7, n_buffer : 50000, eps : 31.7%
# n_episode :9680, score : -4.7, n_buffer : 50000, eps : 31.6%
# n_episode :9700, score : -3.8, n_buffer : 50000, eps : 31.5%
# n_episode :9720, score : -3.3, n_buffer : 50000, eps : 31.4%
# n_episode :9740, score : -3.9, n_buffer : 50000, eps : 31.3%
# n_episode :9760, score : -4.2, n_buffer : 50000, eps : 31.2%
# n_episode :9780, score : -2.1, n_buffer : 50000, eps : 31.1%
# n_episode :9800, score : -4.7, n_buffer : 50000, eps : 31.0%
# n_episode :9820, score : -4.2, n_buffer : 50000, eps : 30.9%
# n_episode :9840, score : -4.5, n_buffer : 50000, eps : 30.8%
# n_episode :9860, score : -4.0, n_buffer : 50000, eps : 30.7%
# n_episode :9880, score : -3.3, n_buffer : 50000, eps : 30.6%
# n_episode :9900, score : -3.1, n_buffer : 50000, eps : 30.5%
# n_episode :9920, score : -3.2, n_buffer : 50000, eps : 30.4%
# n_episode :9940, score : -2.8, n_buffer : 50000, eps : 30.3%
# n_episode :9960, score : -5.0, n_buffer : 50000, eps : 30.2%
# n_episode :9980, score : -2.8, n_buffer : 50000, eps : 30.1%

# %% [markdown]
# #Vis

# %%
q.eval()
# Out:
# Qnet(
#   (fc1): Linear(in_features=4, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=4, bias=True)
# )

# %%
import numpy as np
import matplotlib.pyplot as plt

s = env.reset()

# %%
for _ in range(10):
  a = q.sample_action(torch.from_numpy(s).float(), 0)
  s_prime, r, find = env.step(a)
  s = s_prime
  a = q.sample_action(torch.from_numpy(s).float(), 0)

  W, H = 5, 5
  self_x, self_y = env.x, env.y
  self_apple_x, self_apple_y = env.apple_x, env.apple_y

  x = np.arange(0, W+1, 1)
  y = np.arange(0, H+1, 1)

  plt.plot()
  plt.grid(True, axis = 'y', color = 'black', alpha = 0.5, linestyle= '--')
  plt.grid(True, axis = 'x', color = 'black', alpha = 0.5, linestyle= '--')
  plt.axis([0, W, 0, H])

  # agent
  plt.fill([self_x, self_x, self_x+1, self_x+1], [self_y, self_y+1, self_y+1, self_y], facecolor = 'red', alpha = 0.5)

  # action vis
  if a == 1:
      plt.arrow(self_x+0.3, self_y+0.5, -0.5, 0, facecolor = 'k', ec = 'k', head_width = 0.1, head_length = 0.1)
  elif a == 2:
      plt.arrow(self_x+0.5, self_y+0.7, 0, 0.5, facecolor = 'k', ec = 'k', head_width = 0.1, head_length = 0.1)
  elif a == 3:
      plt.arrow(self_x+0.7, self_y+0.5, 0.5, 0, facecolor = 'k', ec = 'k', head_width = 0.1, head_length = 0.1)
  elif a == 0:
      plt.arrow(self_x+0.5, self_y+0.3, 0, -0.5, facecolor = 'k', ec = 'k', head_width = 0.1, head_length = 0.1)


  # apple
  plt.fill([self_apple_x, self_apple_x, self_apple_x+1, self_apple_x+1], [self_apple_y, self_apple_y+1, self_apple_y+1, self_apple_y], facecolor = 'orange')
  plt.show()
